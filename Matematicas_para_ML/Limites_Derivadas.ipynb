# %% [markdown]
# <a href="https://colab.research.google.com/github/alfxer69/TemasPythonEjercicios/blob/main/Matematicas_para_ML/Limites_Derivadas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cálculo I: Límites & Derivadas
#
# Este tema, Cálculo I: Límites y Derivadas, introduce el campo matemático del cálculo -el estudio de las tasas de cambio- desde cero. Es esencial porque el cálculo de derivadas a través de la diferenciación es la base de la optimización de la mayoría de los algoritmos de aprendizaje automático, incluidos los utilizados en el aprendizaje profundo, como la retropropagación y el descenso de gradiente estocástico.
#
#
# A través de la exposición mesurada de la teoría junto con ejemplos interactivos, desarrollarás una comprensión práctica de cómo se utiliza el cálculo para calcular límites y diferenciar funciones. También aprenderá a aplicar la diferenciación automática en las populares bibliotecas de aprendizaje automático TensorFlow 2 y PyTorch. El contenido cubierto en esta clase es en sí mismo fundamental para varios otros temas de la serie Fundamentos del Aprendizaje Automático, especialmente Cálculo II y Optimización.
#
#
# En el transcurso del estudio de este tema, vamos a:
#
#
# Desarrollar una comprensión de lo que está pasando bajo el capó de los algoritmos de aprendizaje automático, incluidos los utilizados para el aprendizaje profundo.
#
# Ser capaz de comprender más íntimamente los detalles de los papeles de aprendizaje automático, así como muchos de los otros temas que subyacen ML, incluyendo el cálculo de derivadas parciales, estadísticas y algoritmos de optimización.
#
# Calcular las derivadas de funciones, incluyendo el uso de AutoDiff en las populares bibliotecas TensorFlow 2 y PyTorch.
#
# Tenga en cuenta que este cuaderno Jupyter no está diseñado para funcionar por sí solo. Es el código que acompaña a una clase o a los vídeos de la serie Fundamentos Matemáticos de Machine Learning de Frogames Formación, que ofrecen detalles sobre lo siguiente:
#
#
# Segmento 1: Límites
#
#
# Qué es el cálculo
#
# Breve historia del cálculo
#
# El método de agotamiento
#
# Cálculo de límites
#
# Segmento 2: Cálculo de Derivadas con Diferenciación
#
#
# El Método Delta
#
# La Ecuación de Diferenciación
#
# Notación de derivadas
#
# La regla de la potencia
#
# Regla de los múltiplos constantes
#
# Regla de la suma
#
# Regla del producto
#
# Regla del cociente
#
# La regla de la cadena
#
# Segmento 3: Diferenciación Automática
#
#
#
# AutoDiff con PyTorch
#
# AutoDiff con TensorFlow 2
#
# Aprendizaje automático mediante diferenciación
#
# Funciones de Coste (o Pérdida)
#
# El Futuro: Programación Diferenciable

# %% [markdown]
# Segmento 1: Límites

# %% [markdown]
# El Cálculo de Infinitesimales

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(-10,10,10000) #inicio,final,puntos

# %% [markdown]
# Si y=x2+2x+2:

# %%
y=x**2+2*x+2

# %%
fig,ax=plt.subplots()
_=ax.plot(x,y)

# %% [markdown]
# No hay líneas rectas en la curva.
# Sin embargo, si nos acercamos infinitamente, observamos curvas que se aproximan a rectas.
#
# Esto nos permite encontrar una pendiente m (tangente) en cualquier punto de la curva, incluso identificar dónde m=0:

# %%
fig,ax=plt.subplots()
ax.set_xlim([-2,0])
ax.set_ylim([0,2])
ax.plot(x,y)

# %%
fig,ax=plt.subplots()
ax.set_xlim([-1.5,-0.5])
ax.set_ylim([0.5,1.5])
ax.plot(x,y)

# %%
fig,ax=plt.subplots()
ax.set_xlim([-1.1,-0.9])
ax.set_ylim([0.9,1.1])
ax.plot(x,y)

# %%
fig,ax=plt.subplots()
ax.set_xlim([-1.01,-0.99])
ax.set_ylim([0.99,1.01])
ax.plot(x,y)

# %% [markdown]
# Limites

# %%
fig,ax=plt.subplots()
plt.axvline(x=0,color='lightgray')
plt.axhline(y=0,color='lightgray')
plt.xlim(-5,10)
plt.ylim(-10,80)
plt.axvline(x=5,color='purple',linestyle='--')
plt.axhline(y=37,color='purple',linestyle='--')
plt.grid(color='gray',linestyle='--')
ax.plot(x,y)

# %% [markdown]
# limx→1x2−1x−1

# %%
def my_fxn(my_x):
  my_y=(my_x**2-1)/(my_x-1)
  return my_y

# %%
my_fxn(2)
# Out:
# 3.0

# %%
# Descomentar la siguiente línea produce un error de 'división por cero':
#my_fxn(1)

# %%
my_fxn(0.9)
# Out:
# 1.9

# %%
my_fxn(0.999)
# Out:
# 1.9989999999999712

# %%
my_fxn(1.1)
# Out:
# 2.1

# %%
my_fxn(1.0001)
# Out:
# 2.0000999999993923

# %%
y=my_fxn(x)

# %%
fig,ax=plt.subplots()
plt.axvline(x=0,color='lightgray')
plt.axhline(y=0,color='lightgray')
plt.xlim(-1,5)
plt.ylim(-1,5)
plt.axvline(x=1,color='purple',linestyle='--')
plt.axhline(y=2,color='purple',linestyle='--')
plt.grid(color='#dadada',linestyle='--')
ax.plot(x,y)

# %% [markdown]
# limx→0sin(x)/x

# %%
def sin_fxn(my_x):
  my_y=np.sin(my_x)/my_x
  return my_y

# %%
# Descomentar la siguiente línea produce un error de 'división por cero':
#y = sin_fxn(0)

# %%
sin_fxn(0.1)
# Out:
# np.float64(0.9983341664682815)

# %%
sin_fxn(0.001)
# Out:
# np.float64(0.9999998333333416)

# %%
sin_fxn(-0.1)
# Out:
# np.float64(0.9983341664682815)

# %%
sin_fxn(-0.001)
# Out:
# np.float64(0.9999998333333416)

# %%
y=sin_fxn(x)

# %%
fig,ax=plt.subplots()
ax.axvline(x=0,color='lightgray',linestyle='--')
ax.axhline(y=0,color='lightgray',linestyle='--')
plt.xlim(-10,10)
plt.ylim(-1,2)
plt.axvline(x=0,color='purple',linestyle='--')
plt.axhline(y=1,color='purple',linestyle='--')
plt.grid(color='#dadada')
plt.plot(x,y)

# %% [markdown]
# limx→∞25/x

# %%
def inf_fxn(my_x):
  my_y=25/my_x
  return my_y

# %%
inf_fxn(1e3)
# Out:
# 0.025

# %%
inf_fxn(1e6)
# Out:
# 2.5e-05

# %%
y=inf_fxn(x)

# %%
fig,ax=plt.subplots()
plt.axvline(x=0,color='lightgray')
plt.axhline(y=0,color='lightgray')
plt.xlim(-10,10)
plt.ylim(-300,300)
plt.grid(color='#dadada',linestyle='--')
plt.plot(x,y)

# %%
left_x=x[x<0]
right_x=x[x>0]

# %%
left_y=inf_fxn(left_x)
right_y=inf_fxn(right_x)

# %%
fig,ax=plt.subplots()
plt.axvline(x=0,color='lightgray',linestyle='--')
plt.axhline(y=0,color='lightgray',linestyle='--')
plt.xlim(-10,10)
plt.ylim(-300,300)
ax.plot(left_x,left_y,color='C0')
ax.plot(right_x,right_y,color='C0')

# %% [markdown]
# limx→0(x2−1)/(x−1)

# %%
def my_fxn(my_x):
  my_y=(my_x**2-1)/(my_x-1)
  return my_y

# %%
my_fxn(2)
# Out:
# 3.0

# %%
my_fxn(0.999)
# Out:
# 1.9989999999999712

# %%
my_fxn(1.001)
# Out:
# 2.0009999999999177

# %%
y=my_fxn(x)

# %%
fig,ax=plt.subplots()
plt.axvline(x=0,color='lightgray',linestyle='--')
plt.axhline(y=0,color='lightgray',linestyle='--')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.axvline(x=0,color='purple',linestyle='--')
plt.axhline(y=1,color='purple',linestyle='--')
plt.grid(color='#dadada',linestyle='--')
ax.plot(x,y)

# %% [markdown]
# limx→−5(x2−25)/(x+5)

# %%
def my_fxn(my_x):
  my_y=(my_x**2-25)/(my_x+5)
  return my_y

# %%
my_fxn(-4.999)
# Out:
# -9.999000000000748

# %%
my_fxn(-5.001)
# Out:
# -10.000999999999252

# %%
my_fxn(-4.99999)
# Out:
# -9.999989999821537

# %%
y=my_fxn(x)

# %%
fig,ax=plt.subplots()
plt.axvline(x=0,color='lightgray',linestyle='--')
plt.axhline(y=0,color='lightgray',linestyle='--')
plt.xlim(-10,10)
plt.ylim(-20,20)
plt.axvline(x=-5,color='purple',linestyle='--')
plt.axhline(y=-10,color='purple',linestyle='--')
plt.grid(color='#dadada',linestyle='--')
ax.plot(x,y)

# %% [markdown]
# limx→4(x2−2x−8)/(x−4)

# %%
def my_fxn(my_x):
  my_y=(my_x**2-2*my_x-8)/(my_x-4)
  return my_y

# %%
my_fxn(3.99999)
# Out:
# 5.999989999999173

# %%
my_fxn(4.00001)
# Out:
# 6.000009999823192

# %%
y=my_fxn(x)

# %%
fig,ax=plt.subplots()
plt.axvline(x=0,color='lightgray',linestyle='--')
plt.axhline(y=0,color='lightgray',linestyle='--')
plt.xlim(-10,10)
plt.ylim(-20,20)
plt.axvline(x=4,color='purple',linestyle='--')
plt.axhline(y=6,color='purple',linestyle='--')
plt.grid(color='#dadada',linestyle='--')
ax.plot(x,y)

# %% [markdown]
# limx→−∞25/x

# %%
def inf_fxn(my_x):
  my_y=25/my_x
  return my_y

# %%
inf_fxn(-1e3)
# Out:
# -0.025

# %%
inf_fxn(-1e6)
# Out:
# -2.5e-05

# %%
y=25/x

# %%
fig,ax=plt.subplots()
plt.axvline(x=0,color='lightgray',linestyle='--')
plt.axhline(y=0,color='lightgray',linestyle='--')
plt.xlim(-10,10)
plt.ylim(-300,300)
plt.grid(color='#dadada',linestyle='--')
plt.plot(x,y)

# %% [markdown]
# limx→0 25/x

# %%
def my_fxn(my_x):
  my_y=25/my_x
  return my_y

# %%
my_fxn(0.1)
# Out:
# 250.0

# %%
my_fxn(-0.1)
# Out:
# -250.0

# %%
y=my_fxn(x)

# %%
fig,ax=plt.subplots()
plt.axvline(x=0,color='lightgray',linestyle='--')
plt.axhline(y=0,color='lightgray',linestyle='--')
plt.xlim(-0.5,0.5)
plt.ylim(-1500,1500)
plt.grid(color='#dadada',linestyle='--')
plt.axvline(x=0.1,color='purple',linestyle='--')
plt.axhline(y=250,color='purple',linestyle='--')
plt.axvline(x=-0.1,color='purple',linestyle='--')
plt.axhline(y=-250,color='purple',linestyle='--')
plt.grid(color='#dadada',linestyle='--')
plt.plot(x,y)
