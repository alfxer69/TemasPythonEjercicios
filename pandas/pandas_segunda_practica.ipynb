# %%
import pandas as pd
import numpy as np

# %%
ruta=r'C:\Users\Usuario\Desktop\TemasPythonEjercicios\pandas\plantilla_clima_argentina_csv.csv'

df=pd.read_csv(ruta,header=0,encoding='latin1')
df.head(10)
# Out:
#                      NOMBRE     PROVINCIA LATITUD LATITUD.1 LONGITUD  \
# 0                       NaN           NaN    [gr]     [min]     [gr]
# 1          BASE BELGRANO II     ANTARTIDA     -77        52      -34
# 2  BASE CARLINI (EX JUBANY)     ANTARTIDA     -62        14      -58
# 3            BASE ESPERANZA     ANTARTIDA     -63        23      -56
# 4             BASE MARAMBIO     ANTARTIDA     -64        14      -56
# 5              BASE ORCADAS     ANTARTIDA     -60        44      -44
# 6           BASE SAN MARTIN     ANTARTIDA     -68         7      -67
# 7                 AZUL AERO  BUENOS AIRES     -36        49      -59
# 8         BAHIA BLANCA AERO  BUENOS AIRES     -38        42      -62
# 9             BENITO JUAREZ  BUENOS AIRES     -37        42      -59
#
#   LONGITUD.1 ALTURA      NRO NroOACI
# 0      [min]    [m]      NaN     NaN
# 1         37    256  89034.0    SAYB
# 2         39     11  89053.0    SAYJ
# 3         59     24  88963.0    SAYE
# ...

# %%
df=df.fillna('')
df
# Out:
#                        NOMBRE            PROVINCIA LATITUD LATITUD.1 LONGITUD  \
# 0                                                     [gr]     [min]     [gr]
# 1            BASE BELGRANO II            ANTARTIDA     -77        52      -34
# 2    BASE CARLINI (EX JUBANY)            ANTARTIDA     -62        14      -58
# 3              BASE ESPERANZA            ANTARTIDA     -63        23      -56
# 4               BASE MARAMBIO            ANTARTIDA     -64        14      -56
# ..                        ...                  ...     ...       ...      ...
# 114  SANTIAGO DEL ESTERO AERO  SANTIAGO DEL ESTERO     -27        45      -64
# 115  TERMAS DE RIO HONDO AERO  SANTIAGO DEL ESTERO     -27        30      -64
# 116           RIO GRANDE B.A.     TIERRA DEL FUEGO     -53        46      -67
# 117              USHUAIA AERO     TIERRA DEL FUEGO     -54        50      -68
# 118              TUCUMAN AERO              TUCUMAN     -26        50      -65
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                        NOMBRE            PROVINCIA LATITUD LATITUD.1 LONGITUD  \
# 0                                                     [gr]     [min]     [gr]
# 1            BASE BELGRANO II            ANTARTIDA     -77        52      -34
# 2    BASE CARLINI (EX JUBANY)            ANTARTIDA     -62        14      -58
# 3              BASE ESPERANZA            ANTARTIDA     -63        23      -56
# 4               BASE MARAMBIO            ANTARTIDA     -64        14      -56
# ..                        ...                  ...     ...       ...      ...
# 114  SANTIAGO DEL ESTERO AERO  SANTIAGO DEL ESTERO     -27        45      -64
# 115  TERMAS DE RIO HONDO AERO  SANTIAGO DEL ESTERO     -27        30      -64
# 116           RIO GRANDE B.A.     TIERRA DEL FUEGO     -53        46      -67
# 117              USHUAIA AERO     TIERRA DEL FUEGO     -54        50      -68
# 118              TUCUMAN AERO              TUCUMAN     -26        50      -65
#
# ...

# %%
df.describe()
# Out:
#        NOMBRE     PROVINCIA LATITUD LATITUD.1 LONGITUD LONGITUD.1 ALTURA  NRO  \
# count     119           119     119       119      119        119    119  119
# unique    119            26      37        53       23         57    107  119
# top            BUENOS AIRES     -34        35      -58          8     24
# freq        1            26      13         6       15          6      3    1
#
#        NroOACI
# count      119
# unique     118
# top
# freq         2

# %%
df.set_index("NOMBRE",inplace=True)
df.head(10)
# Out:
#                              PROVINCIA LATITUD LATITUD.1 LONGITUD LONGITUD.1  \
# NOMBRE
#                                           [gr]     [min]     [gr]      [min]
# BASE BELGRANO II             ANTARTIDA     -77        52      -34         37
# BASE CARLINI (EX JUBANY)     ANTARTIDA     -62        14      -58         39
# BASE ESPERANZA               ANTARTIDA     -63        23      -56         59
# BASE MARAMBIO                ANTARTIDA     -64        14      -56         37
# BASE ORCADAS                 ANTARTIDA     -60        44      -44         44
# BASE SAN MARTIN              ANTARTIDA     -68         7      -67          6
# AZUL AERO                 BUENOS AIRES     -36        49      -59         53
# BAHIA BLANCA AERO         BUENOS AIRES     -38        42      -62          9
# BENITO JUAREZ             BUENOS AIRES     -37        42      -59         47
#
#                          ALTURA      NRO NroOACI
# NOMBRE
#                             [m]
# ...

# %%
df.reset_index(inplace=True)
df.head(10)
# Out:
#                      NOMBRE     PROVINCIA LATITUD LATITUD.1 LONGITUD  \
# 0                                            [gr]     [min]     [gr]
# 1          BASE BELGRANO II     ANTARTIDA     -77        52      -34
# 2  BASE CARLINI (EX JUBANY)     ANTARTIDA     -62        14      -58
# 3            BASE ESPERANZA     ANTARTIDA     -63        23      -56
# 4             BASE MARAMBIO     ANTARTIDA     -64        14      -56
# 5              BASE ORCADAS     ANTARTIDA     -60        44      -44
# 6           BASE SAN MARTIN     ANTARTIDA     -68         7      -67
# 7                 AZUL AERO  BUENOS AIRES     -36        49      -59
# 8         BAHIA BLANCA AERO  BUENOS AIRES     -38        42      -62
# 9             BENITO JUAREZ  BUENOS AIRES     -37        42      -59
#
#   LONGITUD.1 ALTURA      NRO NroOACI
# 0      [min]    [m]
# 1         37    256  89034.0    SAYB
# 2         39     11  89053.0    SAYJ
# 3         59     24  88963.0    SAYE
# ...

# %%
df.dtypes
# Out:
# NOMBRE        object
# PROVINCIA     object
# LATITUD       object
# LATITUD.1     object
# LONGITUD      object
# LONGITUD.1    object
# ALTURA        object
# NRO           object
# NroOACI       object
# dtype: object

# %%
df.columns
# Out:
# Index(['NOMBRE', 'PROVINCIA', 'LATITUD', 'LATITUD.1', 'LONGITUD', 'LONGITUD.1',
#        'ALTURA', 'NRO', 'NroOACI'],
#       dtype='object')

# %%
# Convertir columnas a tipo numérico
df.loc[1:,'LATITUD']=pd.to_numeric(df.loc[1:,'LATITUD'],errors='coerce')
df.loc[1:,'LATITUD.1']=pd.to_numeric(df.loc[1:,'LATITUD.1'],errors='coerce')
df.dtypes
# Out:
# NOMBRE        object
# PROVINCIA     object
# LATITUD       object
# LATITUD.1     object
# LONGITUD      object
# LONGITUD.1    object
# ALTURA        object
# NRO           object
# NroOACI       object
# dtype: object

# %%
# Crear una nueva columna que sea el producto de las dos columnas de latitud
df['LATITUD_TOTAL']=df.loc[1:,'LATITUD']*df.loc[1:,'LATITUD.1']
df.head(10)
# Out:
#                      NOMBRE     PROVINCIA LATITUD LATITUD.1 LONGITUD  \
# 0                                            [gr]     [min]     [gr]
# 1          BASE BELGRANO II     ANTARTIDA     -77        52      -34
# 2  BASE CARLINI (EX JUBANY)     ANTARTIDA     -62        14      -58
# 3            BASE ESPERANZA     ANTARTIDA     -63        23      -56
# 4             BASE MARAMBIO     ANTARTIDA     -64        14      -56
# 5              BASE ORCADAS     ANTARTIDA     -60        44      -44
# 6           BASE SAN MARTIN     ANTARTIDA     -68         7      -67
# 7                 AZUL AERO  BUENOS AIRES     -36        49      -59
# 8         BAHIA BLANCA AERO  BUENOS AIRES     -38        42      -62
# 9             BENITO JUAREZ  BUENOS AIRES     -37        42      -59
#
#   LONGITUD.1 ALTURA      NRO NroOACI LATITUD_TOTAL
# 0      [min]    [m]                            NaN
# 1         37    256  89034.0    SAYB         -4004
# 2         39     11  89053.0    SAYJ          -868
# ...

# %%
df.fillna('',inplace=True)
df.head(10)
# Out:
#                      NOMBRE     PROVINCIA LATITUD LATITUD.1 LONGITUD  \
# 0                                            [gr]     [min]     [gr]
# 1          BASE BELGRANO II     ANTARTIDA     -77        52      -34
# 2  BASE CARLINI (EX JUBANY)     ANTARTIDA     -62        14      -58
# 3            BASE ESPERANZA     ANTARTIDA     -63        23      -56
# 4             BASE MARAMBIO     ANTARTIDA     -64        14      -56
# 5              BASE ORCADAS     ANTARTIDA     -60        44      -44
# 6           BASE SAN MARTIN     ANTARTIDA     -68         7      -67
# 7                 AZUL AERO  BUENOS AIRES     -36        49      -59
# 8         BAHIA BLANCA AERO  BUENOS AIRES     -38        42      -62
# 9             BENITO JUAREZ  BUENOS AIRES     -37        42      -59
#
#   LONGITUD.1 ALTURA      NRO NroOACI LATITUD_TOTAL
# 0      [min]    [m]
# 1         37    256  89034.0    SAYB         -4004
# 2         39     11  89053.0    SAYJ          -868
# ...

# %%
df.loc[1:,'LONGITUD']=df.loc[1:,'LONGITUD'].astype(float)
df.loc[1:,'LONGITUD.1']=df.loc[1:,'LONGITUD.1'].astype(float)
df.dtypes
# Out:
# NOMBRE           object
# PROVINCIA        object
# LATITUD          object
# LATITUD.1        object
# LONGITUD         object
# LONGITUD.1       object
# ALTURA           object
# NRO              object
# NroOACI          object
# LATITUD_TOTAL    object
# dtype: object

# %%
df['LONGITUD_TOTAL']=df.loc[1:,'LONGITUD']*df.loc[1:,'LONGITUD.1']
df.head(10)
# Out:
#                      NOMBRE     PROVINCIA LATITUD LATITUD.1 LONGITUD  \
# 0                                            [gr]     [min]     [gr]
# 1          BASE BELGRANO II     ANTARTIDA     -77        52    -34.0
# 2  BASE CARLINI (EX JUBANY)     ANTARTIDA     -62        14    -58.0
# 3            BASE ESPERANZA     ANTARTIDA     -63        23    -56.0
# 4             BASE MARAMBIO     ANTARTIDA     -64        14    -56.0
# 5              BASE ORCADAS     ANTARTIDA     -60        44    -44.0
# 6           BASE SAN MARTIN     ANTARTIDA     -68         7    -67.0
# 7                 AZUL AERO  BUENOS AIRES     -36        49    -59.0
# 8         BAHIA BLANCA AERO  BUENOS AIRES     -38        42    -62.0
# 9             BENITO JUAREZ  BUENOS AIRES     -37        42    -59.0
#
#   LONGITUD.1 ALTURA      NRO NroOACI LATITUD_TOTAL LONGITUD_TOTAL
# 0      [min]    [m]                                           NaN
# 1       37.0    256  89034.0    SAYB         -4004        -1258.0
# ...

# %%
df.fillna('',inplace=True)
df.head(10)
# Out:
#                      NOMBRE     PROVINCIA LATITUD LATITUD.1 LONGITUD  \
# 0                                            [gr]     [min]     [gr]
# 1          BASE BELGRANO II     ANTARTIDA     -77        52    -34.0
# 2  BASE CARLINI (EX JUBANY)     ANTARTIDA     -62        14    -58.0
# 3            BASE ESPERANZA     ANTARTIDA     -63        23    -56.0
# 4             BASE MARAMBIO     ANTARTIDA     -64        14    -56.0
# 5              BASE ORCADAS     ANTARTIDA     -60        44    -44.0
# 6           BASE SAN MARTIN     ANTARTIDA     -68         7    -67.0
# 7                 AZUL AERO  BUENOS AIRES     -36        49    -59.0
# 8         BAHIA BLANCA AERO  BUENOS AIRES     -38        42    -62.0
# 9             BENITO JUAREZ  BUENOS AIRES     -37        42    -59.0
#
#   LONGITUD.1 ALTURA      NRO NroOACI LATITUD_TOTAL LONGITUD_TOTAL
# 0      [min]    [m]
# 1       37.0    256  89034.0    SAYB         -4004        -1258.0
# ...

# %%
df['LATITUD_TOTAL']=df.loc[1:,'LATITUD_TOTAL'].astype(float)
df[df['LATITUD_TOTAL']<-200]
# Out:
#                        NOMBRE            PROVINCIA LATITUD LATITUD.1 LONGITUD  \
# 1            BASE BELGRANO II            ANTARTIDA     -77        52    -34.0
# 2    BASE CARLINI (EX JUBANY)            ANTARTIDA     -62        14    -58.0
# 3              BASE ESPERANZA            ANTARTIDA     -63        23    -56.0
# 4               BASE MARAMBIO            ANTARTIDA     -64        14    -56.0
# 5                BASE ORCADAS            ANTARTIDA     -60        44    -44.0
# ..                        ...                  ...     ...       ...      ...
# 114  SANTIAGO DEL ESTERO AERO  SANTIAGO DEL ESTERO     -27        45    -64.0
# 115  TERMAS DE RIO HONDO AERO  SANTIAGO DEL ESTERO     -27        30    -64.0
# 116           RIO GRANDE B.A.     TIERRA DEL FUEGO     -53        46    -67.0
# 117              USHUAIA AERO     TIERRA DEL FUEGO     -54        50    -68.0
# 118              TUCUMAN AERO              TUCUMAN     -26        50    -65.0
#
# ...

# %%
df[df['NOMBRE'].str.contains('BUENOS')]
# Out:
#                        NOMBRE        PROVINCIA LATITUD LATITUD.1 LONGITUD  \
# 34  BUENOS AIRES OBSERVATORIO  CAPITAL FEDERAL     -34        35    -58.0
#
#    LONGITUD.1 ALTURA      NRO NroOACI  LATITUD_TOTAL LONGITUD_TOTAL
# 34       29.0     25  87585.0    SABA        -1190.0        -1682.0

# %%
df['NOMBRE_COMPLETO']=df['NOMBRE']+' '+df['PROVINCIA']
df.head(10)
# Out:
#                      NOMBRE     PROVINCIA LATITUD LATITUD.1 LONGITUD  \
# 0                                            [gr]     [min]     [gr]
# 1          BASE BELGRANO II     ANTARTIDA     -77        52    -34.0
# 2  BASE CARLINI (EX JUBANY)     ANTARTIDA     -62        14    -58.0
# 3            BASE ESPERANZA     ANTARTIDA     -63        23    -56.0
# 4             BASE MARAMBIO     ANTARTIDA     -64        14    -56.0
# 5              BASE ORCADAS     ANTARTIDA     -60        44    -44.0
# 6           BASE SAN MARTIN     ANTARTIDA     -68         7    -67.0
# 7                 AZUL AERO  BUENOS AIRES     -36        49    -59.0
# 8         BAHIA BLANCA AERO  BUENOS AIRES     -38        42    -62.0
# 9             BENITO JUAREZ  BUENOS AIRES     -37        42    -59.0
#
#   LONGITUD.1 ALTURA      NRO NroOACI  LATITUD_TOTAL LONGITUD_TOTAL  \
# 0      [min]    [m]                             NaN
# 1       37.0    256  89034.0    SAYB        -4004.0        -1258.0
# ...
